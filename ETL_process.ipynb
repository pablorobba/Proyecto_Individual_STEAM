# %% [markdown]
# # ETL process

# %% [markdown]
# ## We import the libraries

# %%
import pandas as pd
import numpy as np
import json
import ast
import re

# %% [markdown]
# ## Then, we open the JSONs

# %%
df_games = pd.read_json(r'Datasets\output_steam_games.json' ,lines=True)

# %%
data_list = []       # List to save the JSON's dictionaries for every line

file_path = r"Datasets\australian_user_reviews.json"

# Open the archive and process every line
with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        try:
            # Use ast.literal_eval to transform the line to a dictionary
            json_data = ast.literal_eval(line)
            data_list.append(json_data)
        except ValueError as e:
            print(f"Error in line: {line}")
            continue

df_user_reviews = pd.DataFrame(data_list)

# %%
# same process here:
data_list = []   

file_path = r"Datasets\australian_users_items.json"

with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        try:
            json_data = ast.literal_eval(line)
            data_list.append(json_data)
        except ValueError as e:
            print(f"Error in line: {line}")
            continue

df_user_items = pd.DataFrame(data_list)

# %% [markdown]
# ## Datasets visualization and first data explorations

# %%
df_games.head()
# Out:
#   publisher genres app_name title   url release_date  tags reviews_url specs  \
# 0      None   None     None  None  None         None  None        None  None
# 1      None   None     None  None  None         None  None        None  None
# 2      None   None     None  None  None         None  None        None  None
# 3      None   None     None  None  None         None  None        None  None
# 4      None   None     None  None  None         None  None        None  None
#
#   price  early_access  id developer
# 0  None           NaN NaN      None
# 1  None           NaN NaN      None
# 2  None           NaN NaN      None
# 3  None           NaN NaN      None
# 4  None           NaN NaN      None

# %%
df_user_items.head()
# Out:
#              user_id  items_count           steam_id  \
# 0  76561197970982479          277  76561197970982479
# 1            js41637          888  76561198035864385
# 2          evcentric          137  76561198007712555
# 3         Riot-Punch          328  76561197963445855
# 4              doctr          541  76561198002099482
#
#                                             user_url  \
# 0  http://steamcommunity.com/profiles/76561197970...
# 1               http://steamcommunity.com/id/js41637
# 2             http://steamcommunity.com/id/evcentric
# 3            http://steamcommunity.com/id/Riot-Punch
# 4                 http://steamcommunity.com/id/doctr
#
#                                                items
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 2  [{'item_id': '1200', 'item_name': 'Red Orchest...
# 3  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 4  [{'item_id': '300', 'item_name': 'Day of Defea...

# %%
df_user_reviews.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#                                              reviews
# 0  [{'funny': '', 'posted': 'Posted November 5, 2...
# 1  [{'funny': '', 'posted': 'Posted June 24, 2014...
# 2  [{'funny': '', 'posted': 'Posted February 3.',...
# 3  [{'funny': '', 'posted': 'Posted October 14, 2...
# 4  [{'funny': '3 people found this review funny',...

# %%
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120445 entries, 0 to 120444
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     24083 non-null  object
#  1   genres        28852 non-null  object
#  2   app_name      32133 non-null  object
#  3   title         30085 non-null  object
#  4   url           32135 non-null  object
#  5   release_date  30068 non-null  object
#  6   tags          31972 non-null  object
#  7   reviews_url   32133 non-null  object
#  8   specs         31465 non-null  object
#  9   price         30758 non-null  object
#  10  early_access  32135 non-null  float64
#  11  id            32133 non-null  float64
#  12  developer     28836 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 11.9+ MB

# %%
df_user_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88310 entries, 0 to 88309
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      88310 non-null  object
#  1   items_count  88310 non-null  int64
#  2   steam_id     88310 non-null  object
#  3   user_url     88310 non-null  object
#  4   items        88310 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.4+ MB

# %%
df_user_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25799 entries, 0 to 25798
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   25799 non-null  object
#  1   user_url  25799 non-null  object
#  2   reviews   25799 non-null  object
# dtypes: object(3)
# memory usage: 604.8+ KB

# %% [markdown]
# We see that the dataframes have a lot of unnested data and completely empty rows, we are gonna work with that

# %% [markdown]
# # Now, we are going to do an specific ETL for every dataframe

# %% [markdown]
# # ETL for df_games

# %% [markdown]
# drop the empty columns

# %%
df_games = df_games.dropna(how ="all").reset_index(drop=True)

# %% [markdown]
# We search for the items with the same id

# %%
duplicated_rows_games = df_games[df_games.duplicated(subset = "id", keep=False)]
duplicated_rows_games
# Out:
#                                                publisher               genres  \
# 74                                                  None                 None
# 13894                                 Bethesda Softworks             [Action]
# 14573                                 Bethesda Softworks             [Action]
# 30961  Warner Bros. Interactive Entertainment, Feral ...  [Action, Adventure]
#
#                                              app_name  \
# 74                                               None
# 13894                Wolfenstein II: The New Colossus
# 14573                Wolfenstein II: The New Colossus
# 30961  Batman: Arkham City - Game of the Year Edition
#
#                                                 title  \
# 74                                               None
# 13894                Wolfenstein II: The New Colossus
# 14573                Wolfenstein II: The New Colossus
# 30961  Batman: Arkham City - Game of the Year Edition
#
#                                                      url release_date  \
# 74                        http://store.steampowered.com/         None
# 13894          http://store.steampowered.com/app/612880/   2017-10-26
# 14573  http://store.steampowered.com/app/612880/Wolfe...   2017-10-26
# 30961           http://store.steampowered.com/app/200260   2012-09-07
#
#                                                     tags  \
# 74                                                  None
# 13894  [Action, FPS, Gore, Violent, Alternate History...
# 14573  [Action, FPS, Gore, Violent, Alternate History...
# 30961  [Action, Open World, Batman, Adventure, Stealt...
#
#                                              reviews_url  \
# 74                                                  None
# 13894  http://steamcommunity.com/app/612880/reviews/?...
# 14573  http://steamcommunity.com/app/612880/reviews/?...
# 30961                                               None
#
#                                                    specs  price  early_access  \
# 74                                                  None  19.99           0.0
# 13894  [Single-player, Steam Achievements, Full contr...  59.99           0.0
# 14573  [Single-player, Steam Achievements, Full contr...  59.99           0.0
# 30961  [Single-player, Steam Achievements, Steam Trad...  19.99           0.0
#
#              id                                   developer
# 74          NaN                                        None
# 13894  612880.0                               Machine Games
# 14573  612880.0                               Machine Games
# 30961       NaN  Rocksteady Studios,Feral Interactive (Mac)

# %% [markdown]
# The first row is empty, so we have to drop it. The bethesda's rows are the same, so we are dropping one of them.
# We have to look the Batman's game case

# %%
batman_mask = df_games["title"] == "Batman: Arkham City - Game of the Year Edition"
batman_game = df_games[batman_mask]
batman_game
# Out:
#                                                publisher               genres  \
# 1068   Warner Bros. Interactive Entertainment, Feral ...  [Action, Adventure]
# 30961  Warner Bros. Interactive Entertainment, Feral ...  [Action, Adventure]
#
#                                              app_name  \
# 1068   Batman: Arkham City - Game of the Year Edition
# 30961  Batman: Arkham City - Game of the Year Edition
#
#                                                 title  \
# 1068   Batman: Arkham City - Game of the Year Edition
# 30961  Batman: Arkham City - Game of the Year Edition
#
#                                                      url release_date  \
# 1068   http://store.steampowered.com/app/200260/Batma...   2012-09-07
# 30961           http://store.steampowered.com/app/200260   2012-09-07
#
#                                                     tags  \
# 1068   [Action, Open World, Batman, Adventure, Stealt...
# 30961  [Action, Open World, Batman, Adventure, Stealt...
#
#                                              reviews_url  \
# 1068   http://steamcommunity.com/app/200260/reviews/?...
# 30961                                               None
#
#                                                    specs  price  early_access  \
# 1068   [Single-player, Steam Achievements, Steam Trad...  19.99           0.0
# 30961  [Single-player, Steam Achievements, Steam Trad...  19.99           0.0
#
#              id                                   developer
# 1068   200260.0  Rocksteady Studios,Feral Interactive (Mac)
# 30961       NaN  Rocksteady Studios,Feral Interactive (Mac)

# %% [markdown]
# The two rows have the same game, so we drop one, the one with no id

# %%
df_games = df_games.drop([30961,74,13894])

# %% [markdown]
# We look at the genres and tags columns, since are very similar

# %%
empty_rows_genres = df_games[df_games['genres'].isna()] 
empty_rows_genres
# Out:
#       publisher genres                                    app_name  \
# 4          None   None                               Log Challenge
# 11         None   None                        Icarus Six Sixty Six
# 19         None   None                               After Life VR
# 20         None   None                                  Kitty Hawk
# 22         None   None                                  Mortars VR
# ...         ...    ...                                         ...
# 32118      None   None   Robotpencil Presents: Exercise: Brushwork
# 32119      None   None  Robotpencil Presents: Creative Composition
# 32120      None   None                            The Gamble House
# 32121      None   None    Kalen Chock Presents: 2017 Free Tutorial
# 32134      None   None                                 Maze Run VR
#
#                                             title  \
# 4                                            None
# 11                                           None
# 19                                           None
# 20                                           None
# 22                                           None
# ...                                           ...
# 32118   Robotpencil Presents: Exercise: Brushwork
# 32119  Robotpencil Presents: Creative Composition
# 32120                            The Gamble House
# 32121    Kalen Chock Presents: 2017 Free Tutorial
# 32134                                        None
#
#                                                      url release_date  \
# 4      http://store.steampowered.com/app/773570/Log_C...         None
# 11     http://store.steampowered.com/app/724910/Icaru...         None
# 19     http://store.steampowered.com/app/772590/After...         None
# 20     http://store.steampowered.com/app/640250/Kitty...         None
# 22     http://store.steampowered.com/app/711440/Morta...         None
# ...                                                  ...          ...
# 32118  http://store.steampowered.com/app/775640/Robot...   2018-01-03
# 32119  http://store.steampowered.com/app/777930/Robot...   2018-01-03
# 32120  http://store.steampowered.com/app/775370/The_G...   2016-11-19
# 32121  http://store.steampowered.com/app/777950/Kalen...   2018-01-03
# 32134  http://store.steampowered.com/app/681550/Maze_...         None
#
#                                                     tags  \
# 4                        [Action, Indie, Casual, Sports]
# 11                                              [Casual]
# 19                             [Early Access, Indie, VR]
# 20      [Early Access, Action, Adventure, Indie, Casual]
# 22     [Early Access, Strategy, Action, Indie, Casual...
# ...                                                  ...
# 32118                  [Design & Illustration, Tutorial]
# 32119                  [Design & Illustration, Tutorial]
# 32120                                            [Movie]
# 32121                  [Design & Illustration, Tutorial]
# 32134  [Early Access, Adventure, Indie, Action, Simul...
#
#                                              reviews_url  \
# 4      http://steamcommunity.com/app/773570/reviews/?...
# 11     http://steamcommunity.com/app/724910/reviews/?...
# 19     http://steamcommunity.com/app/772590/reviews/?...
# 20     http://steamcommunity.com/app/640250/reviews/?...
# 22     http://steamcommunity.com/app/711440/reviews/?...
# ...                                                  ...
# 32118  http://steamcommunity.com/app/775640/reviews/?...
# 32119  http://steamcommunity.com/app/777930/reviews/?...
# 32120  http://steamcommunity.com/app/775370/reviews/?...
# 32121  http://steamcommunity.com/app/777950/reviews/?...
# 32134  http://steamcommunity.com/app/681550/reviews/?...
#
#                                                    specs price  early_access  \
# 4      [Single-player, Full controller support, HTC V...  2.99           0.0
# 11     [Single-player, HTC Vive, Tracked Motion Contr...  Free           0.0
# 19     [Single-player, HTC Vive, Tracked Motion Contr...  4.99           1.0
# 20     [Single-player, Steam Leaderboards, HTC Vive, ...  2.99           1.0
# 22     [Single-player, Multi-player, Online Multi-Pla...  0.99           1.0
# ...                                                  ...   ...           ...
# 32118                                               None  3.99           0.0
# 32119                                               None  3.99           0.0
# 32120                               [Captions available]  4.99           0.0
# 32121                                               None  Free           0.0
# 32134  [Single-player, Stats, Steam Leaderboards, HTC...  4.99           1.0
#
#              id developer
# 4      773570.0      None
# 11     724910.0      None
# 19     772590.0      None
# 20     640250.0      None
# 22     711440.0      None
# ...         ...       ...
# 32118  775640.0      None
# 32119  777930.0      None
# 32120  775370.0      None
# 32121  777950.0      None
# 32134  681550.0      None
#
# [3282 rows x 13 columns]

# %%
empty_rows_tags = df_games[df_games['tags'].isna()] 
empty_rows_tags
# Out:
#                             publisher               genres  \
# 279                   Her Interactive          [Adventure]
# 298    SQUARE ENIX, Eidos Interactive  [Action, Adventure]
# 309                   Freeze Tag Inc.             [Casual]
# 310                   Freeze Tag Inc.             [Casual]
# 358               Paradox Interactive                 None
# ...                               ...                  ...
# 31625                       PlayFirst             [Casual]
# 31627                       PlayFirst         [Simulation]
# 31639                   Sandlot Games                 None
# 31652                  Strategy First              [Indie]
# 31808            Q Entertainment Inc.             [Casual]
#
#                                           app_name  \
# 279    Nancy Drew®: Ransom of the Seven Ships Demo
# 298                               Mini Ninjas Demo
# 309                         Freeze Tag Fun Pack #2
# 310                         Freeze Tag Fun Pack #1
# 358     Europa Universalis III: Heir to the Throne
# ...                                            ...
# 31625                                    Zenerchi®
# 31627      Wedding Dash® 2: Rings Around the World
# 31639                      Super Granny Collection
# 31652             Bad Rats: the Rats' Revenge Demo
# 31808                        LUMINES™ Advance Pack
#
#                                              title  \
# 279    Nancy Drew®: Ransom of the Seven Ships Demo
# 298                               Mini Ninjas Demo
# 309                         Freeze Tag Fun Pack #2
# 310                         Freeze Tag Fun Pack #1
# 358     Europa Universalis III: Heir to the Throne
# ...                                            ...
# 31625                                    Zenerchi®
# 31627      Wedding Dash® 2: Rings Around the World
# 31639                      Super Granny Collection
# 31652             Bad Rats: the Rats' Revenge Demo
# 31808                        LUMINES™ Advance Pack
#
#                                                      url release_date  tags  \
# 279    http://store.steampowered.com/app/31990/Nancy_...   2009-07-21  None
# 298    http://store.steampowered.com/app/35050/Mini_N...   2009-08-19  None
# 309    http://store.steampowered.com/app/39392/Freeze...   2009-09-23  None
# 310    http://store.steampowered.com/app/39391/Freeze...   1999-11-30  None
# 358    http://store.steampowered.com/app/25806/Europa...   2009-12-15  None
# ...                                                  ...          ...   ...
# 31625  http://store.steampowered.com/app/37290/Zenerchi/   2009-08-12  None
# 31627  http://store.steampowered.com/app/37280/Weddin...   2009-08-12  None
# 31639  http://store.steampowered.com/app/36270/Super_...   2009-07-17  None
# 31652  http://store.steampowered.com/app/34910/Bad_Ra...   2009-07-20  None
# 31808  http://store.steampowered.com/app/11920/LUMINE...   2008-04-18  None
#
#                                              reviews_url  \
# 279    http://steamcommunity.com/app/31990/reviews/?b...
# 298    http://steamcommunity.com/app/35050/reviews/?b...
# 309    http://steamcommunity.com/app/39392/reviews/?b...
# 310    http://steamcommunity.com/app/39391/reviews/?b...
# 358    http://steamcommunity.com/app/25806/reviews/?b...
# ...                                                  ...
# 31625  http://steamcommunity.com/app/37290/reviews/?b...
# 31627  http://steamcommunity.com/app/37280/reviews/?b...
# 31639  http://steamcommunity.com/app/36270/reviews/?b...
# 31652  http://steamcommunity.com/app/34910/reviews/?b...
# 31808  http://steamcommunity.com/app/11920/reviews/?b...
#
#                                                    specs  price  early_access  \
# 279                           [Single-player, Game demo]   None           0.0
# 298                           [Single-player, Game demo]   None           0.0
# 309                                      [Single-player]  19.99           0.0
# 310                                      [Single-player]  19.99           0.0
# 358    [Single-player, Multi-player, Downloadable Con...   9.99           0.0
# ...                                                  ...    ...           ...
# 31625                                    [Single-player]   9.99           0.0
# 31627                                    [Single-player]   9.99           0.0
# 31639                                    [Single-player]  14.99           0.0
# 31652                         [Single-player, Game demo]   None           0.0
# 31808                                    [Single-player]   7.99           0.0
#
#             id                                          developer
# 279    31990.0                                    Her Interactive
# 298    35050.0                                     IO Interactive
# 309    39392.0                              Freeze Tag Inc.,iQ212
# 310    39391.0  Freeze Tag Inc.,Joju Games,Linksolutions Ltd.,...
# 358    25806.0                                Paradox Interactive
# ...        ...                                                ...
# 31625  37290.0                                   Red Rocket Games
# 31627  37280.0                                           Sarbakan
# 31639  36270.0                                      Sandlot Games
# 31652  34910.0                              Invent4 Entertainment
# 31808  11920.0                               Q Entertainment Inc.
#
# [162 rows x 13 columns]

# %% [markdown]
# The tags and genres columns have similar atributes (very similar). We are going to drop the tags column, since we are not going to use it in the api and the machine learning model. So, as not to waste the information, we are going to fill the empty values in genres with the values in tags that are not empty.

# %%
df_games['genre'] = df_games['genres'].combine_first(df_games['tags'])
df_games = df_games.drop(['tags', 'genres'], axis=1)
df_games
# Out:
#               publisher                  app_name                     title  \
# 0             Kotoshiro       Lost Summoner Kitty       Lost Summoner Kitty
# 1      Making Fun, Inc.                 Ironbound                 Ironbound
# 2          Poolians.com   Real Pool 3D - Poolians   Real Pool 3D - Poolians
# 3                  彼岸领域                   弹炸人2222                   弹炸人2222
# 4                  None             Log Challenge                      None
# ...                 ...                       ...                       ...
# 32130   Ghost_RUS Games            Colony On Mars            Colony On Mars
# 32131            Sacada  LOGistICAL: South Africa  LOGistICAL: South Africa
# 32132      Laush Studio             Russian Roads             Russian Roads
# 32133          SIXNAILS       EXIT 2 - Directions       EXIT 2 - Directions
# 32134              None               Maze Run VR                      None
#
#                                                      url release_date  \
# 0      http://store.steampowered.com/app/761140/Lost_...   2018-01-04
# 1      http://store.steampowered.com/app/643980/Ironb...   2018-01-04
# 2      http://store.steampowered.com/app/670290/Real_...   2017-07-24
# 3         http://store.steampowered.com/app/767400/2222/   2017-12-07
# 4      http://store.steampowered.com/app/773570/Log_C...         None
# ...                                                  ...          ...
# 32130  http://store.steampowered.com/app/773640/Colon...   2018-01-04
# 32131  http://store.steampowered.com/app/733530/LOGis...   2018-01-04
# 32132  http://store.steampowered.com/app/610660/Russi...   2018-01-04
# 32133  http://store.steampowered.com/app/658870/EXIT_...   2017-09-02
# 32134  http://store.steampowered.com/app/681550/Maze_...         None
#
#                                              reviews_url  \
# 0      http://steamcommunity.com/app/761140/reviews/?...
# 1      http://steamcommunity.com/app/643980/reviews/?...
# 2      http://steamcommunity.com/app/670290/reviews/?...
# 3      http://steamcommunity.com/app/767400/reviews/?...
# 4      http://steamcommunity.com/app/773570/reviews/?...
# ...                                                  ...
# 32130  http://steamcommunity.com/app/773640/reviews/?...
# 32131  http://steamcommunity.com/app/733530/reviews/?...
# 32132  http://steamcommunity.com/app/610660/reviews/?...
# 32133  http://steamcommunity.com/app/658870/reviews/?...
# 32134  http://steamcommunity.com/app/681550/reviews/?...
#
#                                                    specs         price  \
# 0                                        [Single-player]          4.99
# 1      [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 2      [Single-player, Multi-player, Online Multi-Pla...  Free to Play
# 3                                        [Single-player]          0.99
# 4      [Single-player, Full controller support, HTC V...          2.99
# ...                                                  ...           ...
# 32130                [Single-player, Steam Achievements]          1.99
# 32131  [Single-player, Steam Achievements, Steam Clou...          4.99
# 32132  [Single-player, Steam Achievements, Steam Trad...          1.99
# 32133   [Single-player, Steam Achievements, Steam Cloud]          4.99
# 32134  [Single-player, Stats, Steam Leaderboards, HTC...          4.99
#
#        early_access        id                 developer  \
# 0               0.0  761140.0                 Kotoshiro
# 1               0.0  643980.0          Secret Level SRL
# 2               0.0  670290.0              Poolians.com
# 3               0.0  767400.0                      彼岸领域
# 4               0.0  773570.0                      None
# ...             ...       ...                       ...
# 32130           0.0  773640.0        Nikita "Ghost_RUS"
# 32131           0.0  733530.0                    Sacada
# 32132           0.0  610660.0  Laush Dmitriy Sergeevich
# 32133           0.0  658870.0             xropi,stev3ns
# 32134           1.0  681550.0                      None
#
#                                                    genre
# 0          [Action, Casual, Indie, Simulation, Strategy]
# 1                   [Free to Play, Indie, RPG, Strategy]
# 2      [Casual, Free to Play, Indie, Simulation, Sports]
# 3                            [Action, Adventure, Casual]
# 4                        [Action, Indie, Casual, Sports]
# ...                                                  ...
# 32130              [Casual, Indie, Simulation, Strategy]
# 32131                          [Casual, Indie, Strategy]
# 32132                        [Indie, Racing, Simulation]
# 32133                                    [Casual, Indie]
# 32134  [Early Access, Adventure, Indie, Action, Simul...
#
# [32132 rows x 12 columns]

# %% [markdown]
# The same goes with the appname and title, so we do the same

# %%
df_games['app_title'] = df_games['app_name'].combine_first(df_games['title'])
df_games = df_games.drop(['app_name', 'title'], axis=1)
df_games
# Out:
#               publisher                                                url  \
# 0             Kotoshiro  http://store.steampowered.com/app/761140/Lost_...
# 1      Making Fun, Inc.  http://store.steampowered.com/app/643980/Ironb...
# 2          Poolians.com  http://store.steampowered.com/app/670290/Real_...
# 3                  彼岸领域     http://store.steampowered.com/app/767400/2222/
# 4                  None  http://store.steampowered.com/app/773570/Log_C...
# ...                 ...                                                ...
# 32130   Ghost_RUS Games  http://store.steampowered.com/app/773640/Colon...
# 32131            Sacada  http://store.steampowered.com/app/733530/LOGis...
# 32132      Laush Studio  http://store.steampowered.com/app/610660/Russi...
# 32133          SIXNAILS  http://store.steampowered.com/app/658870/EXIT_...
# 32134              None  http://store.steampowered.com/app/681550/Maze_...
#
#       release_date                                        reviews_url  \
# 0       2018-01-04  http://steamcommunity.com/app/761140/reviews/?...
# 1       2018-01-04  http://steamcommunity.com/app/643980/reviews/?...
# 2       2017-07-24  http://steamcommunity.com/app/670290/reviews/?...
# 3       2017-12-07  http://steamcommunity.com/app/767400/reviews/?...
# 4             None  http://steamcommunity.com/app/773570/reviews/?...
# ...            ...                                                ...
# 32130   2018-01-04  http://steamcommunity.com/app/773640/reviews/?...
# 32131   2018-01-04  http://steamcommunity.com/app/733530/reviews/?...
# 32132   2018-01-04  http://steamcommunity.com/app/610660/reviews/?...
# 32133   2017-09-02  http://steamcommunity.com/app/658870/reviews/?...
# 32134         None  http://steamcommunity.com/app/681550/reviews/?...
#
#                                                    specs         price  \
# 0                                        [Single-player]          4.99
# 1      [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 2      [Single-player, Multi-player, Online Multi-Pla...  Free to Play
# 3                                        [Single-player]          0.99
# 4      [Single-player, Full controller support, HTC V...          2.99
# ...                                                  ...           ...
# 32130                [Single-player, Steam Achievements]          1.99
# 32131  [Single-player, Steam Achievements, Steam Clou...          4.99
# 32132  [Single-player, Steam Achievements, Steam Trad...          1.99
# 32133   [Single-player, Steam Achievements, Steam Cloud]          4.99
# 32134  [Single-player, Stats, Steam Leaderboards, HTC...          4.99
#
#        early_access        id                 developer  \
# 0               0.0  761140.0                 Kotoshiro
# 1               0.0  643980.0          Secret Level SRL
# 2               0.0  670290.0              Poolians.com
# 3               0.0  767400.0                      彼岸领域
# 4               0.0  773570.0                      None
# ...             ...       ...                       ...
# 32130           0.0  773640.0        Nikita "Ghost_RUS"
# 32131           0.0  733530.0                    Sacada
# 32132           0.0  610660.0  Laush Dmitriy Sergeevich
# 32133           0.0  658870.0             xropi,stev3ns
# 32134           1.0  681550.0                      None
#
#                                                    genre  \
# 0          [Action, Casual, Indie, Simulation, Strategy]
# 1                   [Free to Play, Indie, RPG, Strategy]
# 2      [Casual, Free to Play, Indie, Simulation, Sports]
# 3                            [Action, Adventure, Casual]
# 4                        [Action, Indie, Casual, Sports]
# ...                                                  ...
# 32130              [Casual, Indie, Simulation, Strategy]
# 32131                          [Casual, Indie, Strategy]
# 32132                        [Indie, Racing, Simulation]
# 32133                                    [Casual, Indie]
# 32134  [Early Access, Adventure, Indie, Action, Simul...
#
#                       app_title
# 0           Lost Summoner Kitty
# 1                     Ironbound
# 2       Real Pool 3D - Poolians
# 3                       弹炸人2222
# 4                 Log Challenge
# ...                         ...
# 32130            Colony On Mars
# 32131  LOGistICAL: South Africa
# 32132             Russian Roads
# 32133       EXIT 2 - Directions
# 32134               Maze Run VR
#
# [32132 rows x 11 columns]

# %% [markdown]
# We explode the genre row, then we drop the url, reviews_urls and specs columns, since we are not going to use them

# %%
df_games = df_games.explode(["genre"]).reindex()
df_games = df_games.drop(['specs', 'url', 'reviews_url'], axis=1)

# %% [markdown]
# We look to the empty values

# %%
df_games.replace('', None, inplace=True)             #we replace the '' with None
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85627 entries, 0 to 32134
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     59485 non-null  object
#  1   release_date  74929 non-null  object
#  2   price         81934 non-null  object
#  3   early_access  85627 non-null  float64
#  4   id            85627 non-null  float64
#  5   developer     71571 non-null  object
#  6   genre         85489 non-null  object
#  7   app_title     85625 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 5.9+ MB

# %% [markdown]
# We look first at app_name, two useless rows so we drop them

# %%
empty_rows_games = df_games[df_games["app_title"].isna()] 
empty_rows_games
# Out:
#      publisher release_date price  early_access        id developer   genre  \
# 2580      None   2014-08-26  None           0.0  317160.0      None  Action
# 2580      None   2014-08-26  None           0.0  317160.0      None   Indie
#
#      app_title
# 2580      None
# 2580      None

# %%
df_games = df_games.dropna(subset= ['app_title'])

# %% [markdown]
# To the rest, we replace the NaN with "No Data"

# %%
df_games.fillna("No data", inplace=True)
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85625 entries, 0 to 32134
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     85625 non-null  object
#  1   release_date  85625 non-null  object
#  2   price         85625 non-null  object
#  3   early_access  85625 non-null  float64
#  4   id            85625 non-null  float64
#  5   developer     85625 non-null  object
#  6   genre         85625 non-null  object
#  7   app_title     85625 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 5.9+ MB
# C:\Users\Pablo\AppData\Local\Temp\ipykernel_3248\2116514931.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_games.fillna("No data", inplace=True)

# %% [markdown]
# Finally, we export the dataframe to a clean csv

# %%
df_games.to_csv('Datasets/steam_games_clean.csv', index=False, encoding='utf-8')
print('steam_games_clean.csv was saved')
# Out:
# steam_games_clean.csv was saved

# %% [markdown]
# # ETL for df_user_reviews

# %% [markdown]
# First, we unnest (explode) the data

# %%
df_user_reviews_dec = df_user_reviews.explode(['reviews']) #we decompound the reviews column
df_reviews_series = df_user_reviews_dec['reviews'].apply(pd.Series) #create a series from it
df_user_reviews = pd.concat([df_user_reviews_dec, df_reviews_series], axis=1) #we create the defitive dataframe
df_user_reviews.drop('reviews', axis=1, inplace = True) # and then, we delete the leftover column

# %% [markdown]
# Drop the empty rows and the empty column

# %%
df_user_reviews = df_user_reviews.dropna(how ="all").reset_index(drop=True)
df_user_reviews.drop(0, axis=1, inplace = True)       #drop the empty column

# %% [markdown]
# We look if there are duplicated columns

# %%
duplicated_rows_reviews = df_user_reviews[df_user_reviews.duplicated( keep=False)]
duplicated_rows_reviews
# Out:
#                     user_id  \
# 31        76561198156664158
# 115                  Rivtex
# 280    DieMadchenschanderin
# 281    DieMadchenschanderin
# 282    DieMadchenschanderin
# ...                     ...
# 44456     76561198092022514
# 44457     76561198092022514
# 44458     76561198092022514
# 44459     76561198092022514
# 44603        SuchGayMuchWow
#
#                                                 user_url funny  \
# 31     http://steamcommunity.com/profiles/76561198156...
# 115                  http://steamcommunity.com/id/Rivtex
# 280    http://steamcommunity.com/id/DieMadchenschanderin
# 281    http://steamcommunity.com/id/DieMadchenschanderin
# 282    http://steamcommunity.com/id/DieMadchenschanderin
# ...                                                  ...   ...
# 44456  http://steamcommunity.com/profiles/76561198092...
# 44457  http://steamcommunity.com/profiles/76561198092...
# 44458  http://steamcommunity.com/profiles/76561198092...
# 44459  http://steamcommunity.com/profiles/76561198092...
# 44603        http://steamcommunity.com/id/SuchGayMuchWow
#
#                           posted                    last_edited item_id  \
# 31               Posted June 16.                                 252950
# 115    Posted December 23, 2015.                                 298630
# 280      Posted August 29, 2015.                                 346110
# 281      Posted October 5, 2015.   Last edited October 5, 2015.  380770
# 282              Posted June 29.                                 454890
# ...                          ...                            ...     ...
# 44456             Posted July 3.                                 422400
# 44457             Posted June 1.                                 218620
# 44458    Posted August 17, 2014.                                 261820
# 44459  Posted February 17, 2014.                                 224260
# 44603      Posted July 18, 2015.  Last edited December 1, 2015.     730
#
#                                             helpful recommend  \
# 31     0 of 1 people (0%) found this review helpful      True
# 115    0 of 1 people (0%) found this review helpful      True
# 280    0 of 1 people (0%) found this review helpful      True
# 281    0 of 5 people (0%) found this review helpful     False
# 282                                  No ratings yet      True
# ...                                             ...       ...
# 44456                                No ratings yet      True
# 44457                                No ratings yet      True
# 44458                                No ratings yet      True
# 44459                                No ratings yet      True
# 44603                                No ratings yet      True
#
#                                                   review
# 31                                               love it
# 115                                         Its so bosss
# 280    It's a good game, mechanics seem solid and the...
# 281    Well, I don't have much to say about the game....
# 282    It's a pretty good game, not bad for the 49 ce...
# ...                                                  ...
# 44456  Muy entretenido y una coleccion de armas prome...
# 44457  Tiene una jugabilidad y tematica muy buena :D,...
# 44458  Buen juego, no importa el desarrrollo que tien...
# 44459  exelente aporte :D¡¡¡ es una buen mod basado e...
# 44603                10/10 too many children with mikes.
#
# [1736 rows x 9 columns]

# %% [markdown]
# A lot of duplicated, we have to drop them

# %%
print("df_user_reviews's rows are", df_user_reviews.shape[0])
# Out:
# df_user_reviews's rows are 59333

# %%
df_user_reviews = df_user_reviews.drop_duplicates()
print("df_user_reviews's rows are", df_user_reviews.shape[0])
# Out:
# df_user_reviews's rows are 58459

# %% [markdown]
# We look for empty reviews

# %%
df_user_reviews.replace('', None, inplace=True)             #we replace the '' with None
df_user_reviews.head()
# Out:
#              user_id                                           user_url funny  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...  None
# 1  76561197970982479  http://steamcommunity.com/profiles/76561197970...  None
# 2  76561197970982479  http://steamcommunity.com/profiles/76561197970...  None
# 3            js41637               http://steamcommunity.com/id/js41637  None
# 4            js41637               http://steamcommunity.com/id/js41637  None
#
#                       posted last_edited item_id  \
# 0   Posted November 5, 2011.        None    1250
# 1      Posted July 15, 2011.        None   22200
# 2     Posted April 21, 2011.        None   43110
# 3      Posted June 24, 2014.        None  251610
# 4  Posted September 8, 2013.        None  227300
#
#                                            helpful recommend  \
# 0                                   No ratings yet      True
# 1                                   No ratings yet      True
# 2                                   No ratings yet      True
# 3  15 of 20 people (75%) found this review helpful      True
# 4     0 of 1 people (0%) found this review helpful      True
#
#                                               review
# 0  Simple yet with great replayability. In my opi...
# 1               It's unique and worth a playthrough.
# 2  Great atmosphere. The gunplay can be a bit chu...
# 3  I know what you think when you see this title ...
# 4  For a simple (it's actually not all that simpl...

# %%
empty_rows_reviews_funny = df_user_reviews[df_user_reviews["funny"].isna()] 
empty_rows_reviews_funny
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 2      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 3                js41637               http://steamcommunity.com/id/js41637
# 4                js41637               http://steamcommunity.com/id/js41637
# ...                  ...                                                ...
# 59327  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59328  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59329  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59331        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59332        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#       funny                     posted last_edited item_id  \
# 0      None   Posted November 5, 2011.        None    1250
# 1      None      Posted July 15, 2011.        None   22200
# 2      None     Posted April 21, 2011.        None   43110
# 3      None      Posted June 24, 2014.        None  251610
# 4      None  Posted September 8, 2013.        None  227300
# ...     ...                        ...         ...     ...
# 59327  None            Posted July 10.        None     130
# 59328  None            Posted July 10.        None      70
# 59329  None             Posted July 8.        None  362890
# 59331  None            Posted July 20.        None     730
# 59332  None             Posted July 2.        None     440
#
#                                                helpful recommend  \
# 0                                       No ratings yet      True
# 1                                       No ratings yet      True
# 2                                       No ratings yet      True
# 3      15 of 20 people (75%) found this review helpful      True
# 4         0 of 1 people (0%) found this review helpful      True
# ...                                                ...       ...
# 59327                                   No ratings yet      True
# 59328                                   No ratings yet      True
# 59329                                   No ratings yet      True
# 59331                                   No ratings yet      True
# 59332                                   No ratings yet      True
#
#                                                   review
# 0      Simple yet with great replayability. In my opi...
# 1                   It's unique and worth a playthrough.
# 2      Great atmosphere. The gunplay can be a bit chu...
# 3      I know what you think when you see this title ...
# 4      For a simple (it's actually not all that simpl...
# ...                                                  ...
# 59327  if you liked Half life i would really recommen...
# 59328  a must have classic from steam definitely wort...
# 59329  this game is a perfect remake of the original ...
# 59331                                                 :D
# 59332                                     so much fun :D
#
# [50449 rows x 9 columns]

# %%
empty_rows_reviews_review = df_user_reviews[df_user_reviews["review"].isna()] 
empty_rows_reviews_review
# Out:
#                    user_id                                           user_url  \
# 137                  gdxsd                 http://steamcommunity.com/id/gdxsd
# 177      76561198094224872  http://steamcommunity.com/profiles/76561198094...
# 2559     76561198021575394  http://steamcommunity.com/profiles/76561198021...
# 3098             2ZESTY4ME             http://steamcommunity.com/id/2ZESTY4ME
# 4619     76561198093337643  http://steamcommunity.com/profiles/76561198093...
# 10080              cmuir37               http://steamcommunity.com/id/cmuir37
# 13767            Jaysteeny             http://steamcommunity.com/id/Jaysteeny
# 15493               ML8989                http://steamcommunity.com/id/ML8989
# 15981           terencemok            http://steamcommunity.com/id/terencemok
# 19184    76561198079215291  http://steamcommunity.com/profiles/76561198079...
# 20223    76561198079342142  http://steamcommunity.com/profiles/76561198079...
# 20486    76561197971285616  http://steamcommunity.com/profiles/76561197971...
# 22057               shez13                http://steamcommunity.com/id/shez13
# 22058               shez13                http://steamcommunity.com/id/shez13
# 22918             damo4lyf              http://steamcommunity.com/id/damo4lyf
# 23550       FastAsACheetah        http://steamcommunity.com/id/FastAsACheetah
# 25056    76561198061996985  http://steamcommunity.com/profiles/76561198061...
# 25304    76561198098017317  http://steamcommunity.com/profiles/76561198098...
# 25309    76561198072940782  http://steamcommunity.com/profiles/76561198072...
# 25730    76561198081756988  http://steamcommunity.com/profiles/76561198081...
# 25731    76561198081756988  http://steamcommunity.com/profiles/76561198081...
# 26257    76561198108286351  http://steamcommunity.com/profiles/76561198108...
# 26674       CallTripleZero        http://steamcommunity.com/id/CallTripleZero
# 28315          KamuKambing           http://steamcommunity.com/id/KamuKambing
# 28444         Priceless612          http://steamcommunity.com/id/Priceless612
# 28452        diabolical666         http://steamcommunity.com/id/diabolical666
# 28975           DrScottnik            http://steamcommunity.com/id/DrScottnik
# 31647          infidllrone           http://steamcommunity.com/id/infidllrone
# 31955    76561198110176420  http://steamcommunity.com/profiles/76561198110...
# 32466          obviousjosh           http://steamcommunity.com/id/obviousjosh
# 32604    76561198072577997  http://steamcommunity.com/profiles/76561198072...
# 32819           jojoPL1987            http://steamcommunity.com/id/jojoPL1987
# 33785          Kylee_Kylie           http://steamcommunity.com/id/Kylee_Kylie
# 36007    76561198125368693  http://steamcommunity.com/profiles/76561198125...
# 37145          AlienMan180           http://steamcommunity.com/id/AlienMan180
# 39279               _samie                http://steamcommunity.com/id/_samie
# 39357     FifthExclamation      http://steamcommunity.com/id/FifthExclamation
# 39420               sbenji                http://steamcommunity.com/id/sbenji
# 40661       SpatialWheel14        http://steamcommunity.com/id/SpatialWheel14
# 40980               stionk                http://steamcommunity.com/id/stionk
# 41777    76561198065238937  http://steamcommunity.com/profiles/76561198065...
# 43114      STEAM0082987612       http://steamcommunity.com/id/STEAM0082987612
# 43791             bajuthor              http://steamcommunity.com/id/bajuthor
# 44384    76561198071075080  http://steamcommunity.com/profiles/76561198071...
# 45238                 CBMC                  http://steamcommunity.com/id/CBMC
# 45408          viihdavanzo           http://steamcommunity.com/id/viihdavanzo
# 45409          viihdavanzo           http://steamcommunity.com/id/viihdavanzo
# 46707    76561198034829571  http://steamcommunity.com/profiles/76561198034...
# 48199  wazzawazza80profile   http://steamcommunity.com/id/wazzawazza80profile
# 50718    76561198063489150  http://steamcommunity.com/profiles/76561198063...
# 52667    76561198072110631  http://steamcommunity.com/profiles/76561198072...
# 53323     thecommunistbear      http://steamcommunity.com/id/thecommunistbear
# 53806    76561198077684524  http://steamcommunity.com/profiles/76561198077...
# 55425    76561198085883839  http://steamcommunity.com/profiles/76561198085...
# 56488               BNCFan                http://steamcommunity.com/id/BNCFan
# 56502      PLZACCEPTTHEURL       http://steamcommunity.com/id/PLZACCEPTTHEURL
# 57578    76561198100396147  http://steamcommunity.com/profiles/76561198100...
# 57766    76561198102423654  http://steamcommunity.com/profiles/76561198102...
#
#                                   funny                      posted  \
# 137                                 NaN                         NaN
# 177                                 NaN                         NaN
# 2559                                NaN                         NaN
# 3098                               None            Posted March 11.
# 4619                               None  Posted September 19, 2014.
# 10080                               NaN                         NaN
# 13767                               NaN                         NaN
# 15493                               NaN                         NaN
# 15981                              None   Posted December 30, 2014.
# 19184                               NaN                         NaN
# 20223                               NaN                         NaN
# 20486                              None            Posted March 10.
# 22057                              None        Posted May 23, 2014.
# 22058                              None        Posted May 23, 2014.
# 22918                              None   Posted September 2, 2014.
# 23550                              None   Posted September 9, 2013.
# 25056                               NaN                         NaN
# 25304                              None      Posted April 16, 2015.
# 25309                              None      Posted March 16, 2013.
# 25730                              None    Posted October 29, 2013.
# 25731                              None       Posted July 13, 2013.
# 26257                               NaN                         NaN
# 26674                               NaN                         NaN
# 28315                              None    Posted November 7, 2013.
# 28444                               NaN                         NaN
# 28452                               NaN                         NaN
# 28975                               NaN                         NaN
# 31647                              None     Posted August 14, 2015.
# 31955                               NaN                         NaN
# 32466                              None       Posted June 23, 2014.
# 32604                              None   Posted December 20, 2014.
# 32819                               NaN                         NaN
# 33785                               NaN                         NaN
# 36007                              None   Posted November 16, 2015.
# 37145                              None  Posted September 10, 2015.
# 39279                               NaN                         NaN
# 39357                               NaN                         NaN
# 39420                               NaN                         NaN
# 40661                               NaN                         NaN
# 40980                              None     Posted August 23, 2013.
# 41777                               NaN                         NaN
# 43114                              None   Posted December 20, 2015.
# 43791                              None          Posted January 13.
# 44384                               NaN                         NaN
# 45238                              None   Posted November 13, 2014.
# 45408                              None   Posted September 9, 2015.
# 45409                              None   Posted September 9, 2015.
# 46707                              None    Posted October 30, 2014.
# 48199  1 person found this review funny      Posted April 11, 2015.
# 50718                               NaN                         NaN
# 52667                              None      Posted August 9, 2014.
# 53323                               NaN                         NaN
# 53806                              None     Posted August 28, 2014.
# 55425                               NaN                         NaN
# 56488                              None       Posted July 31, 2014.
# 56502                              None       Posted July 25, 2014.
# 57578                               NaN                         NaN
# 57766                               NaN                         NaN
#
#       last_edited item_id                                         helpful  \
# 137           NaN     NaN                                             NaN
# 177           NaN     NaN                                             NaN
# 2559          NaN     NaN                                             NaN
# 3098         None     550                                  No ratings yet
# 4619         None     550                                  No ratings yet
# 10080         NaN     NaN                                             NaN
# 13767         NaN     NaN                                             NaN
# 15493         NaN     NaN                                             NaN
# 15981        None  218620  2 of 2 people (100%) found this review helpful
# 19184         NaN     NaN                                             NaN
# 20223         NaN     NaN                                             NaN
# 20486        None  378041    0 of 1 people (0%) found this review helpful
# 22057        None  211820    0 of 2 people (0%) found this review helpful
# 22058        None  227320                                  No ratings yet
# 22918        None     620  1 of 1 people (100%) found this review helpful
# 23550        None  239660                                  No ratings yet
# 25056         NaN     NaN                                             NaN
# 25304        None     730                                  No ratings yet
# 25309        None     570    0 of 1 people (0%) found this review helpful
# 25730        None   17330                                  No ratings yet
# 25731        None  107410                                  No ratings yet
# 26257         NaN     NaN                                             NaN
# 26674         NaN     NaN                                             NaN
# 28315        None     440                                  No ratings yet
# 28444         NaN     NaN                                             NaN
# 28452         NaN     NaN                                             NaN
# 28975         NaN     NaN                                             NaN
# 31647        None     440                                  No ratings yet
# 31955         NaN     NaN                                             NaN
# 32466        None  221640                                  No ratings yet
# 32604        None     570  1 of 1 people (100%) found this review helpful
# 32819         NaN     NaN                                             NaN
# 33785         NaN     NaN                                             NaN
# 36007        None   24010    0 of 1 people (0%) found this review helpful
# 37145        None    8930                                  No ratings yet
# 39279         NaN     NaN                                             NaN
# 39357         NaN     NaN                                             NaN
# 39420         NaN     NaN                                             NaN
# 40661         NaN     NaN                                             NaN
# 40980        None     570                                  No ratings yet
# 41777         NaN     NaN                                             NaN
# 43114        None  224260                                  No ratings yet
# 43791        None     730  1 of 1 people (100%) found this review helpful
# 44384         NaN     NaN                                             NaN
# 45238        None  289650  6 of 10 people (60%) found this review helpful
# 45408        None  238960                                  No ratings yet
# 45409        None     730                                  No ratings yet
# 46707        None     730  2 of 2 people (100%) found this review helpful
# 48199        None  313010  5 of 11 people (45%) found this review helpful
# 50718         NaN     NaN                                             NaN
# 52667        None     440                                  No ratings yet
# 53323         NaN     NaN                                             NaN
# 53806        None  230410                                  No ratings yet
# 55425         NaN     NaN                                             NaN
# 56488        None  250760                                  No ratings yet
# 56502        None  224540                                  No ratings yet
# 57578         NaN     NaN                                             NaN
# 57766         NaN     NaN                                             NaN
#
#       recommend review
# 137         NaN    NaN
# 177         NaN    NaN
# 2559        NaN    NaN
# 3098       True   None
# 4619       True   None
# 10080       NaN    NaN
# 13767       NaN    NaN
# 15493       NaN    NaN
# 15981      True   None
# 19184       NaN    NaN
# 20223       NaN    NaN
# 20486      True   None
# 22057      True   None
# 22058      True   None
# 22918      True   None
# 23550      True   None
# 25056       NaN    NaN
# 25304      True   None
# 25309      True   None
# 25730      True   None
# 25731      True   None
# 26257       NaN    NaN
# 26674       NaN    NaN
# 28315      True   None
# 28444       NaN    NaN
# 28452       NaN    NaN
# 28975       NaN    NaN
# 31647      True   None
# 31955       NaN    NaN
# 32466      True   None
# 32604      True   None
# 32819       NaN    NaN
# 33785       NaN    NaN
# 36007      True   None
# 37145      True   None
# 39279       NaN    NaN
# 39357       NaN    NaN
# 39420       NaN    NaN
# 40661       NaN    NaN
# 40980      True   None
# 41777       NaN    NaN
# 43114     False   None
# 43791      True   None
# 44384       NaN    NaN
# 45238     False   None
# 45408      True   None
# 45409      True   None
# 46707      True   None
# 48199     False   None
# 50718       NaN    NaN
# 52667      True   None
# 53323       NaN    NaN
# 53806      True   None
# 55425       NaN    NaN
# 56488      True   None
# 56502      True   None
# 57578       NaN    NaN
# 57766       NaN    NaN

# %% [markdown]
# There a lot of people who didnt do any review or nothing, so the data is useless. We can drop all this rows

# %%
df_user_reviews = df_user_reviews.dropna(subset=['funny'])

# %% [markdown]
# We save the clean data in a csv

# %%
archivo_limpio = 'Datasets/user_reviews_clean.csv'
df_user_reviews.to_csv(archivo_limpio, index=False, encoding='utf-8')
print('user_reviews_clean.csv was saved')
# Out:
# user_reviews_clean.csv was saved

# %% [markdown]
# # ETL for df_user_items

# %% [markdown]
# First, we unnest (explode) the data

# %%
#We make the same process that we do in the df_user_reviews dataframe but here we use json_normalize
#function, because with the other way the program got stucked forever
df_user_items_desc = df_user_items.explode(["items"])
df_user_items_desc2 = pd.json_normalize(df_user_items_desc['items']).set_index(df_user_items_desc['items'].index)
df_user_items= pd.concat([df_user_items_desc2, df_user_items_desc], axis=1)
df_user_items.drop('items', axis=1, inplace = True)

# %% [markdown]
# Drop the all empty rows

# %%
df_user_items = df_user_items.dropna(how ="all").reset_index(drop=True)

# %% [markdown]
# See duplicated rows

# %%
duplicated_rows_items = df_user_items[df_user_items.duplicated( keep=False)]
duplicated_rows_items
# Out:
#         item_id                                    item_name  \
# 4346       4000                                  Garry's Mod
# 4347      33910                                       Arma 2
# 4348      33930                  Arma 2: Operation Arrowhead
# 4349     219540  Arma 2: Operation Arrowhead Beta (Obsolete)
# 4350        400                                       Portal
# ...         ...                                          ...
# 4910940  261030                 The Walking Dead: Season Two
# 4910941  273110                Counter-Strike Nexon: Zombies
# 4910942     730             Counter-Strike: Global Offensive
# 4985582     NaN                                          NaN
# 4985583     NaN                                          NaN
#
#          playtime_forever  playtime_2weeks            user_id  items_count  \
# 4346                269.0              0.0  76561198156664158           59
# 4347                162.0              0.0  76561198156664158           59
# 4348                223.0              0.0  76561198156664158           59
# 4349                  0.0              0.0  76561198156664158           59
# 4350                196.0              0.0  76561198156664158           59
# ...                   ...              ...                ...          ...
# 4910940             253.0              0.0  76561198080057659           39
# 4910941               0.0              0.0  76561198080057659           39
# 4910942               0.0              0.0  76561198080057659           39
# 4985582               NaN              NaN         farquadian            0
# 4985583               NaN              NaN         farquadian            0
#
#                   steam_id                                           user_url
# 4346     76561198156664158  http://steamcommunity.com/profiles/76561198156...
# 4347     76561198156664158  http://steamcommunity.com/profiles/76561198156...
# 4348     76561198156664158  http://steamcommunity.com/profiles/76561198156...
# 4349     76561198156664158  http://steamcommunity.com/profiles/76561198156...
# 4350     76561198156664158  http://steamcommunity.com/profiles/76561198156...
# ...                    ...                                                ...
# 4910940  76561198080057659  http://steamcommunity.com/profiles/76561198080...
# 4910941  76561198080057659  http://steamcommunity.com/profiles/76561198080...
# 4910942  76561198080057659  http://steamcommunity.com/profiles/76561198080...
# 4985582  76561198086134170            http://steamcommunity.com/id/farquadian
# 4985583  76561198086134170            http://steamcommunity.com/id/farquadian
#
# [117913 rows x 8 columns]

# %% [markdown]
# Drop duplicated rows

# %%
print("df_user_items's rows are", df_user_items.shape[0])
# Out:
# df_user_items's rows are 5170015

# %%
df_user_items = df_user_items.drop_duplicates()
print("df_user_items's rows are", df_user_items.shape[0])
# Out:
# df_user_items's rows are 5110819

# %% [markdown]
# See the empty values

# %%
df_user_items.replace('', None, inplace=True)             #we replace the '' with None
df_user_items.head()
# Out:
#   item_id                  item_name  playtime_forever  playtime_2weeks  \
# 0      10             Counter-Strike               6.0              0.0
# 1      20      Team Fortress Classic               0.0              0.0
# 2      30              Day of Defeat               7.0              0.0
# 3      40         Deathmatch Classic               0.0              0.0
# 4      50  Half-Life: Opposing Force               0.0              0.0
#
#              user_id  items_count           steam_id  \
# 0  76561197970982479          277  76561197970982479
# 1  76561197970982479          277  76561197970982479
# 2  76561197970982479          277  76561197970982479
# 3  76561197970982479          277  76561197970982479
# 4  76561197970982479          277  76561197970982479
#
#                                             user_url
# 0  http://steamcommunity.com/profiles/76561197970...
# 1  http://steamcommunity.com/profiles/76561197970...
# 2  http://steamcommunity.com/profiles/76561197970...
# 3  http://steamcommunity.com/profiles/76561197970...
# 4  http://steamcommunity.com/profiles/76561197970...

# %%
empty_rows_reviews_items = df_user_items[df_user_items["playtime_forever"].isna()] 
empty_rows_reviews_items
# Out:
#         item_id item_name  playtime_forever  playtime_2weeks  \
# 3733        NaN       NaN               NaN              NaN
# 3849        NaN       NaN               NaN              NaN
# 6019        NaN       NaN               NaN              NaN
# 6523        NaN       NaN               NaN              NaN
# 7237        NaN       NaN               NaN              NaN
# ...         ...       ...               ...              ...
# 5169470     NaN       NaN               NaN              NaN
# 5169471     NaN       NaN               NaN              NaN
# 5169472     NaN       NaN               NaN              NaN
# 5170006     NaN       NaN               NaN              NaN
# 5170014     NaN       NaN               NaN              NaN
#
#                          user_id  items_count           steam_id  \
# 3733                      Wackky            0  76561198039117046
# 3849           76561198079601835            0  76561198079601835
# 6019                    hellom8o            0  76561198117222320
# 6523         starkillershadow553            0  76561198059648579
# 7237                  darkenkane            0  76561198058876001
# ...                          ...          ...                ...
# 5169470        76561198316380182            0  76561198316380182
# 5169471        76561198316970597            0  76561198316970597
# 5169472        76561198318100691            0  76561198318100691
# 5170006  XxLaughingJackClown77xX            0  76561198328759259
# 5170014        edward_tremethick            0  76561198331598578
#
#                                                   user_url
# 3733                   http://steamcommunity.com/id/Wackky
# 3849     http://steamcommunity.com/profiles/76561198079...
# 6019                 http://steamcommunity.com/id/hellom8o
# 6523      http://steamcommunity.com/id/starkillershadow553
# 7237               http://steamcommunity.com/id/darkenkane
# ...                                                    ...
# 5169470  http://steamcommunity.com/profiles/76561198316...
# 5169471  http://steamcommunity.com/profiles/76561198316...
# 5169472  http://steamcommunity.com/profiles/76561198318...
# 5170006  http://steamcommunity.com/id/XxLaughingJackClo...
# 5170014     http://steamcommunity.com/id/edward_tremethick
#
# [16714 rows x 8 columns]

# %%
empty_rows_reviews_items = df_user_items[df_user_items["item_id"].isna()] 
empty_rows_reviews_items
# Out:
#         item_id item_name  playtime_forever  playtime_2weeks  \
# 3733        NaN       NaN               NaN              NaN
# 3849        NaN       NaN               NaN              NaN
# 6019        NaN       NaN               NaN              NaN
# 6523        NaN       NaN               NaN              NaN
# 7237        NaN       NaN               NaN              NaN
# ...         ...       ...               ...              ...
# 5169470     NaN       NaN               NaN              NaN
# 5169471     NaN       NaN               NaN              NaN
# 5169472     NaN       NaN               NaN              NaN
# 5170006     NaN       NaN               NaN              NaN
# 5170014     NaN       NaN               NaN              NaN
#
#                          user_id  items_count           steam_id  \
# 3733                      Wackky            0  76561198039117046
# 3849           76561198079601835            0  76561198079601835
# 6019                    hellom8o            0  76561198117222320
# 6523         starkillershadow553            0  76561198059648579
# 7237                  darkenkane            0  76561198058876001
# ...                          ...          ...                ...
# 5169470        76561198316380182            0  76561198316380182
# 5169471        76561198316970597            0  76561198316970597
# 5169472        76561198318100691            0  76561198318100691
# 5170006  XxLaughingJackClown77xX            0  76561198328759259
# 5170014        edward_tremethick            0  76561198331598578
#
#                                                   user_url
# 3733                   http://steamcommunity.com/id/Wackky
# 3849     http://steamcommunity.com/profiles/76561198079...
# 6019                 http://steamcommunity.com/id/hellom8o
# 6523      http://steamcommunity.com/id/starkillershadow553
# 7237               http://steamcommunity.com/id/darkenkane
# ...                                                    ...
# 5169470  http://steamcommunity.com/profiles/76561198316...
# 5169471  http://steamcommunity.com/profiles/76561198316...
# 5169472  http://steamcommunity.com/profiles/76561198318...
# 5170006  http://steamcommunity.com/id/XxLaughingJackClo...
# 5170014     http://steamcommunity.com/id/edward_tremethick
#
# [16714 rows x 8 columns]

# %% [markdown]
# Same case with the former dataframe, a lot of useless data with NaN values, so we have to drop them

# %%
df_user_items = df_user_items.dropna(subset = ['playtime_forever'])

# %%
df_user_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5094105 entries, 0 to 5170013
# Data columns (total 8 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   item_id           object
#  1   item_name         object
#  2   playtime_forever  float64
#  3   playtime_2weeks   float64
#  4   user_id           object
#  5   items_count       int64
#  6   steam_id          object
#  7   user_url          object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 349.8+ MB

# %%
df_user_items.to_csv('Datasets/user_items_clean.csv', index=False, encoding='utf-8')
print('user_items_clean.csv was saved')
# Out:
# user_items_clean.csv was saved
